# %%
from src.phasorpy.io import __all__
from src.phasorpy.datasets import fetch
from src.phasorpy.lifetime import phasor_coordinates
import numpy
import  matplotlib.pyplot as plt

# %%
data = read_r64('fluorescein_ex760nm.R64')
#data = read_r64(fetch('simfcs.r64'))
intensity = data[0,:,:]
ph = data[1,:,:]
md = data[2,:,:]
g,s=phasor_coordinates(ph,md)
plt.figure()
plt.scatter(g,s,s=.01)
plt.xlim(0,1)
plt.ylim(0,0.6)
# Out:
# (0.0, 0.6)

# %%
data.shape
plt.imshow(intensity)
